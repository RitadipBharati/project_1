# %%
import pandas as pd
import numpy as np  
# readinag given csv file
# and creating dataframe
df1 = pd.read_csv("a2f cs.csv")  
#print(df1)
X = df1.iloc[:,(0)]
#print(X)
E= X.to_numpy()
y = df1.iloc[:,(1)]
#print(y)
E1=y.to_numpy()
#M= df1[0].to_numpy()
#print(E)
#print(E1)

# %%
def INT_TRAP(a,b):
    r=0
    for i in range(len(b)-1):
        h= a[i+1]-a[i]
        f_a=b[i]
        f_b=b[i+1]
        r+=h*(f_a+f_b)/2
    return(r)

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(E,E1,marker=".")
plt.xlabel("E")
plt.ylabel("E1")
plt.xlim(-0.0016,0.0027)
plt.grid()
plt.title("a2F Cs dos1")
plt.show()
i=INT_TRAP(E,E1)
print(i)
I= (1/3.2586)*i*28.9831**2
print(I)
# Out:
# 0.00028378726102651873
# 0.07315626321196946

# %%
df1 = pd.read_csv("a2f cs 2.csv")  
#print(df1)
X = df1.iloc[:,(0)]
#print(X)
E= X.to_numpy()
y = df1.iloc[:,(1)]
#print(y)
E1=y.to_numpy()

# %%
plt.scatter(E,E1,marker=".")
plt.xlabel("E")
plt.ylabel("E1")
plt.xlim(-0.0016,0.0027)
plt.grid()
plt.title("a2F Cs dos2")
plt.show()
i=INT_TRAP(E,E1)
print(i)
I= (1/2.4314)*i*30.7179**2
print(I)
# Out:
# 0.00028378726102651873
# 0.11013352216840656

# %%
df1 = pd.read_csv("a2f cs 3.csv")  
#print(df1)
X = df1.iloc[:,(0)]
#print(X)
E= X.to_numpy()
y = df1.iloc[:,(1)]
#print(y)
E1=y.to_numpy()
plt.scatter(E,E1,marker=".")
plt.xlabel("E")
plt.ylabel("E1")
plt.xlim(-0.0016,0.0027)
plt.grid()
plt.title("a2F Cs dos3")
plt.show()
i=INT_TRAP(E,E1)
print(i)
I= (1/1.9624)*i*31.7338**2
print(I)
# Out:
# 0.00043831540252656145
# 0.22492791502056

# %%
df1 = pd.read_csv("a2f cs 4.csv")  
#print(df1)
X = df1.iloc[:,(0)]
#print(X)
E= X.to_numpy()
y = df1.iloc[:,(1)]
#print(y)
E1=y.to_numpy()
plt.scatter(E,E1,marker=".")
plt.xlabel("E")
plt.ylabel("E1")
plt.xlim(-0.0016,0.0027)
plt.grid()
plt.title("a2F Cs dos4")
plt.show()
i=INT_TRAP(E,E1)
print(i)
I= (1/1.6963)*i*32.2575**2
print(I)
# Out:
# 0.00039424858703595894
# 0.24184042385459456

# %%
df1 = pd.read_csv("a2f cs 5.csv")  
#print(df1)
X = df1.iloc[:,(0)]
#print(X)
E= X.to_numpy()
y = df1.iloc[:,(1)]
#print(y)
E1=y.to_numpy()
plt.scatter(E,E1,marker=".")
plt.xlabel("E")
plt.ylabel("E1")
plt.xlim(-0.0016,0.0027)
plt.grid()
plt.title("a2F Cs dos5")
plt.show()
i=INT_TRAP(E,E1)
print(i)
I= (1/1.5145)*i*32.9248**2
print(I)
# Out:
# 0.0003649847133330774
# 0.26124722660525573

# %%
df1 = pd.read_csv("a2f cs 6.csv")  
#print(df1)
X = df1.iloc[:,(0)]
#print(X)
E= X.to_numpy()
y = df1.iloc[:,(1)]
#print(y)
E1=y.to_numpy()
plt.scatter(E,E1,marker=".")
plt.xlabel("E")
plt.ylabel("E1")
plt.xlim(-0.0016,0.0027)
plt.grid()
plt.title("a2F Cs dos6")
plt.show()
i=INT_TRAP(E,E1)
print(i)
I= (1/1.3812)*i*33.8479**2
print(I)
# Out:
# 0.0003454359316541758
# 0.28653283644279326

# %%
df1 = pd.read_csv("a2f cs 7.csv")  
#print(df1)
X = df1.iloc[:,(0)]
#print(X)
E= X.to_numpy()
y = df1.iloc[:,(1)]
#print(y)
E1=y.to_numpy()
plt.scatter(E,E1,marker=".")
plt.xlabel("E")
plt.ylabel("E1")
plt.xlim(-0.0016,0.0027)
plt.grid()
plt.title("a2F Cs dos7")
plt.show()
i=INT_TRAP(E,E1)
print(i)
I= (1/1.2813)*i*34.9348**2
print(I)
# Out:
# 0.0003324449318706839
# 0.3166543167948437

# %%
df1 = pd.read_csv("a2f cs 8.csv")  
#print(df1)
X = df1.iloc[:,(0)]
#print(X)
E= X.to_numpy()
y = df1.iloc[:,(1)]
#print(y)
E1=y.to_numpy()
plt.scatter(E,E1,marker=".")
plt.xlabel("E")
plt.ylabel("E1")
plt.xlim(-0.0016,0.0027)
plt.grid()
plt.title("a2F Cs dos8")
plt.show()
i=INT_TRAP(E,E1)
print(i)
I= (1/1.2072)*i*36.0281**2
print(I)
# Out:
# 0.00032397272619061167
# 0.3483468941142859

# %%
df1 = pd.read_csv("a2f cs 9.csv")  
#print(df1)
X = df1.iloc[:,(0)]
#print(X)
E= X.to_numpy()
y = df1.iloc[:,(1)]
#print(y)
E1=y.to_numpy()
plt.scatter(E,E1,marker=".")
plt.xlabel("E")
plt.ylabel("E1")
plt.xlim(-0.0016,0.0027)
plt.grid()
plt.title("a2F Cs dos9")
plt.show()
i=INT_TRAP(E,E1)
print(i)
I= (1/1.1544)*i*36.9892**2
print(I)
# Out:
# 0.00031881515963513764
# 0.3778613943620263

# %%
df1 = pd.read_csv("a2f cs 10.csv")  
#print(df1)
X = df1.iloc[:,(0)]
#print(X)
E= X.to_numpy()
y = df1.iloc[:,(1)]
#print(y)
E1=y.to_numpy()
plt.scatter(E,E1,marker=".")
plt.xlabel("E")
plt.ylabel("E1")
plt.xlim(-0.0016,0.0027)
plt.grid()
plt.title("a2F Cs dos10")
plt.show()
i=INT_TRAP(E,E1)
print(i)
I= (1/1.1186)*i*37.7429**2
print(I)
# Out:
# 0.0003160959652032056
# 0.40254521643540464

# %%
df1 = pd.read_csv("a2f k 1.csv")  
#print(df1)
X = df1.iloc[:,(0)]
#print(X)
E= X.to_numpy()
y = df1.iloc[:,(1)]
#print(y)
E1=y.to_numpy()
plt.scatter(E,E1,marker=".")
plt.xlabel("E")
plt.ylabel("E1")
plt.xlim(-0.0016,0.0027)
plt.grid()
plt.title("a2F K dos1")
plt.show()
i=INT_TRAP(E,E1)
print(i)
I= (1/1.1867)*i*28.6808**2
print(I)
# Out:
# 0.0004262242477913573
# 0.29544710084062015

# %%
df1 = pd.read_csv("a2f k 2.csv")  
#print(df1)
X = df1.iloc[:,(0)]
#print(X)
E= X.to_numpy()
y = df1.iloc[:,(1)]
#print(y)
E1=y.to_numpy()
plt.scatter(E,E1,marker=".")
plt.xlabel("E")
plt.ylabel("E1")
plt.xlim(-0.0016,0.0027)
plt.grid()
plt.title("a2F K dos2")
plt.show()
i=INT_TRAP(E,E1)
print(i)
I= (1/1.0890)*i*28.1081**2
print(I)
# Out:
# 0.00037818361563053085
# 0.2743707495832487

# %%
df1 = pd.read_csv("a2f k 3.csv")  
#print(df1)
X = df1.iloc[:,(0)]
#print(X)
E= X.to_numpy()
y = df1.iloc[:,(1)]
#print(y)
E1=y.to_numpy()
plt.scatter(E,E1,marker=".")
plt.xlabel("E")
plt.ylabel("E1")
plt.xlim(-0.0016,0.0027)
plt.grid()
plt.title("a2F K dos3")
plt.show()
i=INT_TRAP(E,E1)
print(i)
I= (1/1.0546)*i*27.4636**2
print(I)
# Out:
# 0.0003433609824020175
# 0.24557158087836542

# %%
df1 = pd.read_csv("a2f k 4.csv")  
#print(df1)
X = df1.iloc[:,(0)]
#print(X)
E= X.to_numpy()
y = df1.iloc[:,(1)]
#print(y)
E1=y.to_numpy()
plt.scatter(E,E1,marker=".")
plt.xlabel("E")
plt.ylabel("E1")
plt.xlim(-0.0016,0.0027)
plt.grid()
plt.title("a2F K dos4")
plt.show()
i=INT_TRAP(E,E1)
print(i)
I= (1/1.0646)*i*26.3083**2
print(I)
# Out:
# 0.00031812510887719897
# 0.20682215436308668

# %%
df1 = pd.read_csv("a2f k 5.csv")  
#print(df1)
X = df1.iloc[:,(0)]
#print(X)
E= X.to_numpy()
y = df1.iloc[:,(1)]
#print(y)
E1=y.to_numpy()
plt.scatter(E,E1,marker=".")
plt.xlabel("E")
plt.ylabel("E1")
plt.xlim(-0.0016,0.0027)
plt.grid()
plt.title("a2F K dos5")
plt.show()
i=INT_TRAP(E,E1)
print(i)
I= (1/1.0908)*i*25.1164**2
print(I)
# Out:
# 0.00030118616178142094
# 0.17418255897892784

# %%
df1 = pd.read_csv("a2f k 6.csv")  
#print(df1)
X = df1.iloc[:,(0)]
#print(X)
E= X.to_numpy()
y = df1.iloc[:,(1)]
#print(y)
E1=y.to_numpy()
plt.scatter(E,E1,marker=".")
plt.xlabel("E")
plt.ylabel("E1")
plt.xlim(-0.0016,0.0027)
plt.grid()
plt.title("a2F K dos6")
plt.show()
i=INT_TRAP(E,E1)
print(i)
I= (1/1.1233)*i*24.0930**2
print(I)
# Out:
# 0.0002904213265233952
# 0.15007712697687992

# %%
df1 = pd.read_csv("a2f k 7.csv")  
#print(df1)
X = df1.iloc[:,(0)]
#print(X)
E= X.to_numpy()
y = df1.iloc[:,(1)]
#print(y)
E1=y.to_numpy()
plt.scatter(E,E1,marker=".")
plt.xlabel("E")
plt.ylabel("E1")
plt.xlim(-0.0016,0.0027)
plt.grid()
plt.title("a2F K dos7")
plt.show()
i=INT_TRAP(E,E1)
print(i)
I= (1/1.1577)*i*23.2805**2
print(I)
# Out:
# 0.00028378726102651873
# 0.13285609101209117

# %%
df1 = pd.read_csv("a2f k 8.csv")  
#print(df1)
X = df1.iloc[:,(0)]
#print(X)
E= X.to_numpy()
y = df1.iloc[:,(1)]
#print(y)
E1=y.to_numpy()
plt.scatter(E,E1,marker=".")
plt.xlabel("E")
plt.ylabel("E1")
plt.xlim(-0.0016,0.0027)
plt.grid()
plt.title("a2F K dos8")
plt.show()
i=INT_TRAP(E,E1)
print(i)
I= (1/1.1907)*i*22.6631**2
print(I)
# Out:
# 0.00028013810688320685
# 0.12083937378832468

# %%
df1 = pd.read_csv("a2f k 9.csv")  
#print(df1)
X = df1.iloc[:,(0)]
#print(X)
E= X.to_numpy()
y = df1.iloc[:,(1)]
#print(y)
E1=y.to_numpy()
plt.scatter(E,E1,marker=".")
plt.xlabel("E")
plt.ylabel("E1")
plt.xlim(-0.0016,0.0027)
plt.grid()
plt.title("a2F K dos9")
plt.show()
i=INT_TRAP(E,E1)
print(i)
I= (1/1.2203)*i*22.2086**2
print(I)
# Out:
# 0.00027855897971456423
# 0.11258821037905614

# %%
df1 = pd.read_csv("a2f k 10.csv")  
#print(df1)
X = df1.iloc[:,(0)]
#print(X)
E= X.to_numpy()
y = df1.iloc[:,(1)]
#print(y)
E1=y.to_numpy()
plt.scatter(E,E1,marker=".")
plt.xlabel("E")
plt.ylabel("E1")
plt.xlim(-0.0016,0.0027)
plt.grid()
plt.title("a2F K dos10")
plt.show()
i=INT_TRAP(E,E1)
print(i)
I= (2/1.2452)*i*21.8846**2
print(I)
# Out:
# 0.00027856462132253446
# 0.21428613345408268

# %%
df1 = pd.read_csv("a2f rb 1.csv")  
#print(df1)
X = df1.iloc[:,(0)]
#print(X)
E= X.to_numpy()
y = df1.iloc[:,(1)]
#print(y)
E1=y.to_numpy()
plt.scatter(E,E1,marker=".")
plt.xlabel("E")
plt.ylabel("E1")
plt.xlim(-0.0016,0.0027)
plt.grid()
plt.title("a2F Rb dos1")
plt.show()
print(INT_TRAP(E,E1))
# Out:
# 0.0004953472765507756

# %%
df1 = pd.read_csv("a2f rb 2.csv")  
#print(df1)
X = df1.iloc[:,(0)]
#print(X)
E= X.to_numpy()
y = df1.iloc[:,(1)]
#print(y)
E1=y.to_numpy()
plt.scatter(E,E1,marker=".")
plt.xlabel("E")
plt.ylabel("E1")
plt.xlim(-0.0016,0.0027)
plt.grid()
plt.title("a2F Rb dos2")
plt.show()
print(INT_TRAP(E,E1))
# Out:
# 0.00042735059180608337

# %%
df1 = pd.read_csv("a2f rb 3.csv")  
#print(df1)
X = df1.iloc[:,(0)]
#print(X)
E= X.to_numpy()
y = df1.iloc[:,(1)]
#print(y)
E1=y.to_numpy()
plt.scatter(E,E1,marker=".")
plt.xlabel("E")
plt.ylabel("E1")
plt.xlim(-0.0016,0.0027)
plt.grid()
plt.title("a2F Rb dos3")
plt.show()
print(INT_TRAP(E,E1))
# Out:
# 0.00038320418990962904

# %%
df1 = pd.read_csv("a2f rb 4.csv")  
#print(df1)
X = df1.iloc[:,(0)]
#print(X)
E= X.to_numpy()
y = df1.iloc[:,(1)]
#print(y)
E1=y.to_numpy()
plt.scatter(E,E1,marker=".")
plt.xlabel("E")
plt.ylabel("E1")
plt.xlim(-0.0016,0.0027)
plt.grid()
plt.title("a2F Rb dos4")
plt.show()
print(INT_TRAP(E,E1))
# Out:
# 0.00035396016457066526

# %%
df1 = pd.read_csv("a2f rb 5.csv")  
#print(df1)
X = df1.iloc[:,(0)]
#print(X)
E= X.to_numpy()
y = df1.iloc[:,(1)]
#print(y)
E1=y.to_numpy()
plt.scatter(E,E1,marker=".")
plt.xlabel("E")
plt.ylabel("E1")
plt.xlim(-0.0016,0.0027)
plt.grid()
plt.title("a2F Rb dos5")
plt.show()
print(INT_TRAP(E,E1))
# Out:
# 0.0003339853128253633

# %%
df1 = pd.read_csv("a2f rb 6.csv")  
#print(df1)
X = df1.iloc[:,(0)]
#print(X)
E= X.to_numpy()
y = df1.iloc[:,(1)]
#print(y)
E1=y.to_numpy()
plt.scatter(E,E1,marker=".")
plt.xlabel("E")
plt.ylabel("E1")
plt.xlim(-0.0016,0.0027)
plt.grid()
plt.title("a2F Rb dos6")
plt.show()
print(INT_TRAP(E,E1))
# Out:
# 0.00032080109901028267

# %%
df1 = pd.read_csv("a2f rb 7.csv")  
#print(df1)
X = df1.iloc[:,(0)]
#print(X)
E= X.to_numpy()
y = df1.iloc[:,(1)]
#print(y)
E1=y.to_numpy()
plt.scatter(E,E1,marker=".")
plt.xlabel("E")
plt.ylabel("E1")
plt.xlim(-0.0016,0.0027)
plt.grid()
plt.title("a2F Rb dos7")
plt.show()
print(INT_TRAP(E,E1))
# Out:
# 0.00031232113745133824

# %%
df1 = pd.read_csv("a2f rb 8.csv")  
#print(df1)
X = df1.iloc[:,(0)]
#print(X)
E= X.to_numpy()
y = df1.iloc[:,(1)]
#print(y)
E1=y.to_numpy()
plt.scatter(E,E1,marker=".")
plt.xlabel("E")
plt.ylabel("E1")
plt.xlim(-0.0016,0.0027)
plt.grid()
plt.title("a2F Rb dos8")
plt.show()
print(INT_TRAP(E,E1))
# Out:
# 0.0003070318114586249

# %%
df1 = pd.read_csv("a2f rb 9.csv")  
#print(df1)
X = df1.iloc[:,(0)]
#print(X)
E= X.to_numpy()
y = df1.iloc[:,(1)]
#print(y)
E1=y.to_numpy()
plt.scatter(E,E1,marker=".")
plt.xlabel("E")
plt.ylabel("E1")
plt.xlim(-0.0016,0.0027)
plt.grid()
plt.title("a2F Rb dos9")
plt.show()
print(INT_TRAP(E,E1))
# Out:
# 0.00030421181325049676

# %%
df1 = pd.read_csv("a2f rb 10.csv")  
#print(df1)
X = df1.iloc[:,(0)]
#print(X)
E= X.to_numpy()
y = df1.iloc[:,(1)]
#print(y)
E1=y.to_numpy()
plt.scatter(E,E1,marker=".")
plt.xlabel("E")
plt.ylabel("E1")
plt.xlim(-0.0016,0.0027)
plt.grid()
plt.title("a2F Rb dos10")
plt.show()
print(INT_TRAP(E,E1))
# Out:
# 0.00030317257457564806
